# %%
import sys
import os
sys.path.append(r"C:/Users/It's Blue/news-sentiment-stock-prediction-new/src")
from src.news_analysis import NewsData
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")
